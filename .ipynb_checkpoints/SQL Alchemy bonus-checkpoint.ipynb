# %%
import pandas as pd 
import matplotlib.pyplot as plt
from sqlalchemy import create_engine 
engine = create_engine('postgresql://{user:pass}@localhost:5432/EmployeeSQL') #username and password redacted
connection = engine.connect()

# %%
emp_data = pd.read_sql("SELECT * FROM merge4", connection)
emp_data
# Out:
#        dept_no           dept_name  emp_no  salary emp_title_id  birth_date  \
# 0         d003     Human Resources   10005   78228        s0001  1955-01-21
# 1         d004          Production   10010   72488        e0002  1963-06-01
# 2         d006  Quality Management   10010   72488        e0002  1963-06-01
# 3         d009    Customer Service   10011   42365        s0001  1953-11-07
# 4         d003     Human Resources   10013   40000        s0002  1963-06-07
# ...        ...                 ...     ...     ...          ...         ...
# 331598    d004          Production  499948   40000        e0002  1953-05-24
# 331599    d005         Development  499972   41002        e0003  1957-07-25
# 331600    d008            Research  499985   40000        s0001  1964-12-26
# 331601    d007               Sales  499987   52282        s0001  1961-09-05
# 331602    d002             Finance  499998   40000        s0001  1956-09-05
#
# ...

# %%
#Histogram of Salary Ranges 
plt.hist(emp_data['salary'])
plt.xlabel('Salaries')
plt.ylabel('Employee Numbers')
# Out:
# Text(0, 0.5, 'Employee Numbers')

# %%
#bar chart of average salary by title 

salary_range = emp_data.groupby(['title'])['salary'].mean()
salary_chart = salary_range.plot(kind='bar')
salary_chart.set_xlabel('Employee Title')
salary_chart.set_ylabel('Average Salary')
plt.show()

# %%
emp_data.loc[emp_data["emp_no"]==499942]
# Out:
#       dept_no    dept_name  emp_no  salary emp_title_id  birth_date  \
# 41387    d005  Development  499942   40000        e0004  1963-01-10
#
#       first_name last_name sex   hire_date             title
# 41387      April  Foolsday   F  1997-02-10  Technique Leader
